# %% [markdown]
# # 1. Introduction

# %% [markdown]
# The purpose of this notebook is to perform evaluation of the machine learning models.

# %% [markdown]
# # 2. Setup & Data Load

# %% [markdown]
# Import required modules and packages.

# %%
# import time so that various tasks can be timed
import time

# import math for mathematical functions
import math

# import csv so that results can be read from csv
import csv

# import pandas and numpy for data analysis
import pandas as pd
import numpy as np

# import matplotlib & seaborn for plotting and visualisaion
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns

# %% [markdown]
# Set the max number of columns & rows to display.

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 500)

# %% [markdown]
# Load reports for the relevant month:

# %%
month = "aug"

# %%
segment_report = '/data_analytics/reports/segment_report_' + month + '.csv'
trip_report = '/data_analytics/reports/trip_report_' + month + '.csv'
weekday_report = '/data_analytics/reports/weekday_report_' + month + '.csv'
weekend_report = '/data_analytics/reports/weekend_report_' + month + '.csv'

# %%
df_segment = pd.read_csv(segment_report)
df_trip = pd.read_csv(trip_report)
df_weekday = pd.read_csv(weekday_report)
df_weekend = pd.read_csv(weekend_report)

# %% [markdown]
# # 3. Plot the Weekday Data

# %%
# set columns relevant columns as categorical
df_weekday['hour'] = df_weekday['hour'].astype('category')

# %%
# plot the data
df_weekday.plot(x='hour', y='mae', style='o', title='Weekday MAE')
plt.savefig('/data_analytics/reports/weekday_mae.png')

# %%
# plot the data
df_weekday.plot(x='hour', y='rmse', style='o', title='Weekday RMSE')
plt.savefig('/data_analytics/reports/weekday_rmse.png')

# %% [markdown]
# # 3. Plot the Weekend Data

# %%
# set columns relevant columns as categorical
df_weekend['hour'] = df_weekend['hour'].astype('category')

# %%
# plot the data
df_weekend.plot(x='hour', y='mae', style='o', title='Weekend MAE')
plt.savefig('/data_analytics/reports/weekend_mae.png')

# %%
# plot the data
df_weekend.plot(x='hour', y='rmse', style='o', title='Weekend RMSE')
plt.savefig('/data_analytics/reports/weekend_rmse.png')
